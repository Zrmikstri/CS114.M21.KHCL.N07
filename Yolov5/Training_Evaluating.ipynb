# %% [markdown]
# <a href="https://colab.research.google.com/github/Zrmikstri/CS114.M21.KHCL.N07/blob/main/Yolov5/Training_Evaluating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Truy cập https://drive.google.com/drive/folders/1l_kbP5UgGfaZ0SCrVXsTtc52yGmUlrjh?usp=sharing
# Tạo lối tắt cho thư mục vừa truy cập vào trong My Drive (Drive của tôi).
#
# Bước 1: Tạo lối tắt
#
# ![image.png](data:image/png;base64,...)
# Bước 2: Chọn My Drive (Drive của tôi) và chọn Add Shortcut (Thêm lối tắt)
# ![image.png](data:image/png;base64,...)
#
# Tiếp đến vào Runtime -> Change Runtime type -> Chọn GPU -> Save

# %% [markdown]
# Để chạy một cell chứa code, chỉ cần di chuyển chuột đến cell đó và chọn nút tam giác hiện ở đầu bên trái mỗi cell.

# %% [markdown]
# # Step 1: Install Requirements
#
# Cài đặt các thư viện cần thiết cũng như clone repo Yolov5 mà nhóm em đã chỉnh sửa từ repo gốc (https://github.com/ultralytics/yolov5) để hỗ trợ cho việc che biển số.
#
# Chạy hết 3 cell trong mục này.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Zrmikstri/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12350, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 12350 (delta 40), reused 54 (delta 32), pack-reused 12282
# Receiving objects: 100% (12350/12350), 12.65 MiB | 30.33 MiB/s, done.
# Resolving deltas: 100% (8516/8516), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.1 MB/s
#      |████████████████████████████████| 145 kB 5.1 MB/s
#      |████████████████████████████████| 178 kB 47.9 MB/s
#      |████████████████████████████████| 1.1 MB 63.9 MB/s
#      |████████████████████████████████| 67 kB 7.1 MB/s
#      |████████████████████████████████| 54 kB 3.6 MB/s
#      |████████████████████████████████| 138 kB 74.5 MB/s
#      |████████████████████████████████| 62 kB 1.7 MB/s
#   Building wheel for roboflow (setup.py) ... done
#   Building wheel for wget (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
import os
import cv2
import imutils
import torch
import glob

from google.colab.patches import cv2_imshow
from IPython.display import Image, display, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.11.0+cu113 (Tesla T4)

# %% [markdown]
# # Step 2: Download Our Dataset
#
# * Tải tập dataset mà nhóm dùng để huấn luyện mô hình và đánh giá mô hình.
# * Dataset được nhóm gán nhãn sử dụng Roboflow (https://app.roboflow.com/)
# * Chạy hết 4 cell trong mục này.

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
rf = Roboflow(api_key="76VMxCseoOoXLvJ1qeCi")
project = rf.workspace("license-plate-x8kza").project("license_plate-c6jin")
dataset = project.version(2).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/datasets/license_plate-2 to yolov5pytorch: 100% [218882585 / 218882585] bytes
# Extracting Dataset Version Zip to /content/datasets/license_plate-2 in yolov5pytorch:: 100%|██████████| 6844/6844 [00:05<00:00, 1288.66it/s]

# %%
with open('/content/datasets/license_plate-2/data.yaml','a+') as yamlfile:
        yamlfile.write('\ntest: /content/datasets/license_plate-2/test/images')

# %% [markdown]
# # Step 3: Train Our Custom YOLOv5 model
#
# Trước khi train, ta cần truyền vào một số tham số có file **train.py**:
# - **img:** kích thước ảnh đầu vào. Mặc đinh 640
# - **batch-size:** số lượng mỗi ảnh của từng batch để mô hình xử lý. Truyền -1 để mô hình tự tính toán kích thước của batch. Mặc định 32
# - **epochs:** số epoch để train mô hình. (Thường >= 3000). Mặc định là 300.
# - **data:** đường dẫn của dataset được lưu tại `dataset.location`
# - **weights:** sử dụng weight được train sẵn để tiến hành transfer learning. Nhóm chọn sử dụng yolov5l.pt
# - **cache:** cache hình ảnh để training diễn ra nhanh hơn
# - **patience:** số lượng epoch mà kết quả của mô hình không cải thiện trước khi dừng. Mặc đinh 100 epoch
# - **project:** đường dẫn của thư mục project, nơi mà mô hình sẽ lưu các thư mục chạy thử nghiệm
# - **name:** tên thư mục chạy thử nghiệm, lưu trữ kết quả training, evaluation
#
# Ngoài ra, mô hình còn nhận thêm các tham số khác. Mô hình sẽ sử dụng các giá trị mặc định của tham số nếu tham số để trống. Tham khảo thêm tại soucre code của Ultralytic https://github.com/ultralytics/yolov5.

# %% [markdown]
# ## Training
#
# Để bắt đầu Training, ta sẽ chạy cell dưới dây. Nhóm chọn weight yolov5l.pt đã được pretrain để bắt đầu transfer learning.

# %%
# !python train.py --weights yolov5l.pt --img 640 --batch-size -1 --epochs 1000 --data {dataset.location}/data.yaml  --cache

# %% [markdown]
# Do Colab miễn phí nên thời gian train mô hình có hạn. Do đó, Ultralytic hỗ trợ checkpoint. Nghĩa là mô hình sẽ lưu weight có kết quả tốt nhất dưới tên **best.pt** và weight của epoch cuối cùng trước khi tạm dừng training dưới tên **last.pt**.
#
# Để tiếp tục phần train tạm dừng trước đó, ta sẽ chạy file **train.py** chỉ truyền vào tham số **resume** đường dẫn tới file **last.pt**. Mô hình sẽ tự động train tiếp đến khi tới giới hạn thời gian của Colab hoặc tới khi hết số epoch được xác định ở lần train đầu tiên.
#
# Lưu ý: khi tiếp tục train, chỉ truyền duy nhất tham số **--resume** và đường dẫn tới **last.pt**. Không được truyền các tham số khác.

# %%
# !python train.py --resume /path/to/last.pt

# %% [markdown]
# ## Kết quả training của nhóm
#
# Không nên chạy để tránh mất kết quả

# %%
# !python train.py --weights yolov5l.pt --img 640 --batch-size -1 --epochs 1000 --data {dataset.location}/data.yaml  --cache --project "/content/drive/MyDrive/Project/Yolov5" --name Run_26June22
# Out:
# train: weights=yolov5l.pt, cfg=, data=/content/datasets/license_plate-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/drive/MyDrive/Project/Yolov5, name=Run_26June22, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Project/Yolov5', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=5
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     53850  models.yolo.Detect                      [5, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 468 layers, 46159834 parameters, 46159834 gradients
#
# Transferred 607/613 items from yolov5l.pt
# AMP: checks passed ✅
# AutoBatch: Computing optimal batch size for --imgsz 640
# AutoBatch: CUDA:0 (Tesla T4) 14.76G total, 0.36G reserved, 0.35G allocated, 14.04G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     46159834           0         1.244         57.48         156.4        (1, 3, 640, 640)                    list
#     46159834           0         1.881         52.28         72.16        (2, 3, 640, 640)                    list
#     46159834           0         3.112         55.73         99.65        (4, 3, 640, 640)                    list
#     46159834           0         5.417         97.92         187.5        (8, 3, 640, 640)                    list
#     46159834           0        10.201         187.9         377.1       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size 20 for CUDA:0 12.58G/14.76G (85%) ✅
# Scaled weight_decay = 0.00046875
# optimizer: SGD with parameter groups 101 weight (no decay), 104 weight, 104 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/datasets/license_plate-2/train/labels.cache' images and labels... 2389 found, 0 missing, 4 empty, 0 corrupt: 100% 2389/2389 [00:00<?, ?it/s]
# train: Caching images (2.9GB ram): 100% 2389/2389 [00:13<00:00, 182.15it/s]
# val: Scanning '/content/datasets/license_plate-2/valid/labels.cache' images and labels... 680 found, 0 missing, 1 empty, 0 corrupt: 100% 680/680 [00:00<?, ?it/s]
# val: Caching images (0.8GB ram): 100% 680/680 [00:04<00:00, 148.51it/s]
# Plotting labels to /content/drive/MyDrive/Project/Yolov5/Run_26June222/labels.jpg...
#
# AutoAnchor: 5.44 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Project/Yolov5/Run_26June222
# Starting training for 1000 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/999     12.1G   0.08638   0.02226    0.0389        12       640: 100% 120/120 [01:34<00:00,  1.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.881      0.101       0.13     0.0466
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/999     14.1G   0.05898   0.01292   0.02179        18       640: 100% 120/120 [01:33<00:00,  1.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.685      0.543      0.575      0.252
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/999     14.1G   0.05891  0.009346   0.01314        18       640: 100% 120/120 [01:33<00:00,  1.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868       0.59      0.417      0.429      0.159
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/999     14.1G   0.05218  0.009419  0.009893        19       640: 100% 120/120 [01:34<00:00,  1.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.731      0.671      0.745      0.357
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/999     14.1G   0.04544  0.008393  0.008486        17       640: 100% 120/120 [01:34<00:00,  1.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.689      0.651      0.725      0.349
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/999     14.1G   0.04419  0.008664  0.007649        24       640: 100% 120/120 [01:34<00:00,  1.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.806      0.646      0.743      0.353
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/999     14.1G   0.04128  0.008546  0.006387        23       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.43it/s]
#                  all        680        868      0.764      0.827      0.875      0.415
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/999     14.1G   0.04091  0.008081  0.005168        10       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.804      0.779       0.85       0.44
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/999     14.1G   0.03892  0.007542  0.004499        17       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.844      0.782      0.872      0.463
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/999     14.1G   0.03916   0.00759  0.004899        22       640: 100% 120/120 [01:36<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.882      0.786      0.857      0.443
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/999     14.1G    0.0386  0.007605  0.004792        22       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.833      0.848      0.884      0.469
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/999     14.1G   0.03736    0.0075  0.003619        20       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.896      0.885      0.936      0.463
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/999     14.1G   0.03735  0.007134  0.003195        10       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.868      0.888      0.918      0.478
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/999     14.1G   0.03638  0.006823  0.003242        14       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.904      0.896      0.949      0.497
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/999     14.1G   0.03527  0.006975  0.003284        19       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868       0.88      0.926      0.946      0.509
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/999     14.1G   0.03514  0.006879  0.002977        16       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.869      0.901      0.917      0.482
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/999     14.1G   0.03531  0.006818  0.002383        12       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.882      0.923       0.95      0.518
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/999     14.1G   0.03532  0.007142  0.002702        19       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.926      0.948      0.966       0.51
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/999     14.1G   0.03449  0.006785   0.00215        11       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.905      0.913      0.952      0.529
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/999     14.1G   0.03413  0.006599  0.003001        11       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868        0.9      0.947      0.957      0.522
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/999     14.1G   0.03444  0.006763  0.002266        12       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.891      0.931      0.956      0.522
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/999     14.1G    0.0339  0.006586  0.002433        21       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.907      0.962      0.963      0.546
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/999     14.1G   0.03333  0.006561  0.002053        18       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.921      0.897       0.95      0.527
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/999     14.1G   0.03298  0.006703  0.002073        20       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.909      0.957      0.961      0.543
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/999     14.1G   0.03307  0.006479  0.001669         9       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.922      0.956      0.964      0.553
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     25/999     14.1G   0.03323  0.006445  0.002221        15       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868       0.94      0.933      0.965      0.538
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     26/999     14.1G   0.03285  0.006459   0.00207        10       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.929       0.94      0.965      0.547
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     27/999     14.1G   0.03255  0.006242  0.001783         4       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.897       0.93      0.954      0.518
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     28/999     14.1G   0.03266  0.006462  0.001706        15       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.895      0.932      0.953      0.528
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     29/999     14.1G    0.0333  0.006366  0.002388        16       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.922      0.956      0.968      0.549
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     30
640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.43it/s]
#                  all        680        868      0.922      0.959      0.965      0.554
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    105/999     14.1G   0.02547  0.005205 0.0008627        15       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.933      0.955      0.967      0.559
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    106/999     14.1G   0.02538  0.005301 0.0007846        21       640: 100% 120/120 [01:36<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.932      0.957      0.963       0.56
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    107/999     14.1G   0.02515  0.005335 0.0007637        19       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.928      0.955      0.962      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    108/999     14.1G   0.02524  0.005283 0.0007492        20       640: 100% 120/120 [01:36<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.933       0.93      0.961       0.56
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    109/999     14.1G   0.02519  0.005112   0.00078        11       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868       0.93      0.957       0.96      0.559
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    110/999     14.1G   0.02487  0.005247  0.001078        16       640: 100% 120/120 [01:36<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.919      0.949      0.957       0.56
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    111/999     14.1G   0.02466  0.005272 0.0008317        15       640: 100% 120/120 [01:36<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.936      0.954      0.963      0.566
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    112/999     14.1G   0.02535  0.005147  0.001116        19       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        867      0.928      0.961       0.96      0.553
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    113/999     14.1G   0.02521  0.005088  0.000788        11       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.931      0.956      0.956      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    114/999     14.1G   0.02487  0.005198 0.0008325        15       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868       0.93      0.956      0.959      0.555
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    115/999     14.1G   0.02464  0.005351  0.001313        10       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.931      0.951       0.96      0.573
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    116/999     14.1G   0.02517  0.005539  0.001264        13       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.933      0.937      0.958      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    117/999     14.1G   0.02487  0.005252 0.0008229         9       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        867      0.925      0.951      0.958      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    118/999     14.1G   0.02448  0.005014 0.0007853        13       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.925      0.948      0.954      0.552
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    119/999     14.1G   0.02505  0.005061 0.0009665        10       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.942      0.948      0.964      0.566
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    120/999     14.1G   0.02485  0.005261  0.000912        12       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.929      0.947      0.962      0.558
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    121/999     14.1G   0.02476  0.005241 0.0007242        13       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        867      0.924       0.96      0.962      0.556
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    122/999     14.1G   0.02443  0.005054 0.0008514        10       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        867      0.926      0.951      0.964      0.553
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    123/999     14.1G   0.02415  0.005296 0.0006627        22       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.44it/s]
#                  all        680        868      0.941      0.952      0.965      0.557
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    124/999     14.1G   0.02485  0.005084 0.0007254        16       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.932      0.951      0.963      0.564
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    125/999     14.1G   0.02415  0.004961 0.0006993        21       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        866      0.933      0.948      0.962      0.569
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    126/999     14.1G   0.02414     0.005  0.001072        17       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.927      0.955      0.959      0.556
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    127/999     14.1G   0.02482  0.005131 0.0009754        20       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.46it/s]
#                  all        680        866      0.941      0.945      0.963      0.564
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    128/999     14.1G   0.02435    0.0051  0.000801        10       640: 100% 120/120 [01:35<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:11<00:00,  1.45it/s]
#                  all        680        868      0.933      0.951      0.962      0.555
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    129/999     14.1G   0.02356  0.005012 0.0009347        41       640:  42% 50/120 [00:40<00:56,  1.25it/s]

# %%
# !python train.py --resume /content/drive/MyDrive/Project/Yolov5/Run_24June22/weights/last.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=/content/drive/MyDrive/Project/Yolov5/Run_24June22/weights/last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Resuming training from /content/drive/MyDrive/Project/Yolov5/Run_24June22/weights/last.pt
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Project/Yolov5', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 17.9MB/s]
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     53850  models.yolo.Detect                      [5, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 468 layers, 46159834 parameters, 46159834 gradients
#
# Transferred 613/613 items from /content/drive/MyDrive/Project/Yolov5/Run_24June22/weights/last.pt
# AMP: checks passed ✅
# AutoBatch: Computing optimal batch size for --imgsz 640
# AutoBatch: CUDA:0 (Tesla T4) 14.76G total, 0.36G reserved, 0.35G allocated, 14.04G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     46159834           0         1.244         60.29         144.1        (1, 3, 640, 640)                    list
#     46159834           0         1.881         51.52         75.79        (2, 3, 640, 640)                    list
#     46159834           0         3.112         57.57         104.2        (4, 3, 640, 640)                    list
#     46159834           0         5.417         100.6         196.1        (8, 3, 640, 640)                    list
#     46159834           0        10.201         192.8         401.3       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size 20 for CUDA:0 12.58G/14.76G (85%) ✅
# Scaled weight_decay = 0.00046875
# optimizer: SGD with parameter groups 101 weight (no decay), 104 weight, 104 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/datasets/license_plate-2/train/labels' images and labels...2389 found, 0 missing, 4 empty, 0 corrupt: 100% 2389/2389 [00:01<00:00, 2089.43it/s]
# train: New cache created: /content/datasets/license_plate-2/train/labels.cache
# train: Caching images (2.9GB ram): 100% 2389/2389 [00:13<00:00, 174.99it/s]
# val: Scanning '/content/datasets/license_plate-2/valid/labels' images and labels...680 found, 0 missing, 1 empty, 0 corrupt: 100% 680/680 [00:00<00:00, 754.11it/s]
# val: New cache created: /content/datasets/license_plate-2/valid/labels.cache
# val: Caching images (0.8GB ram): 100% 680/680 [00:03<00:00, 172.47it/s]
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Project/Yolov5/Run_26June222
# Starting training for 1000 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    129/999     12.2G   0.02442  0.005187  0.001022        12       640: 100% 120/120 [01:43<00:00,  1.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.35it/s]
#                  all        680        867      0.936      0.954      0.957      0.558
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    130/999     14.3G   0.02372  0.005121 0.0007329        18       640: 100% 120/120 [01:46<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.32it/s]
#                  all        680        867      0.931      0.955      0.964      0.561
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    131/999     14.3G   0.02381  0.005057 0.0009102        18       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        867      0.933      0.946      0.961      0.559
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    132/999     14.3G   0.02389   0.00513 0.0006124        19       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.937      0.951      0.964      0.567
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    133/999     14.3G   0.02396  0.004812 0.0007165        17       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.32it/s]
#                  all        680        868      0.936      0.944      0.963       0.57
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    134/999     14.3G   0.02352  0.004935  0.000849        24       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.32it/s]
#                  all        680        868      0.938      0.946      0.959      0.563
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    135/999     14.3G   0.02339  0.005075 0.0007158        23       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        867      0.927      0.956       0.96      0.565
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    136/999     14.3G   0.02382  0.005009 0.0008623        10       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.32it/s]
#                  all        680        867       0.94      0.952      0.968      0.567
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    137/999     14.3G   0.02372  0.004972 0.0008467        17       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.31it/s]
#                  all        680        868      0.936       0.95      0.961      0.568
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    138/999     14.3G   0.02396  0.004953 0.0008065        22       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:13<00:00,  1.29it/s]
#                  all        680        868      0.934      0.952      0.959      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    139/999     14.3G   0.02352  0.004914 0.0006813        22       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.928      0.952      0.958      0.557
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    140/999     14.3G    0.0235   0.00492 0.0006599        20       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        867      0.922      0.963      0.958       0.56
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    141/999     14.3G   0.02338  0.004842 0.0008144        10       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.32it/s]
#                  all        680        868       0.93       0.96      0.964      0.563
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    142/999     14.3G   0.02358  0.004833 0.0007784        14       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.927       0.96      0.962      0.568
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    143/999     14.3G   0.02358  0.005013 0.0008667        19       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.936      0.946      0.962      0.565
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    144/999     14.3G   0.02341  0.004941 0.0006396        16       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        867      0.938      0.944      0.963      0.566
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    145/999     14.3G   0.02287  0.004751 0.0006557        12       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.943       0.94      0.966      0.563
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    146/999     14.3G   0.02294  0.004899 0.0006389        19       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.935      0.952      0.963      0.562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    147/999     14.3G   0.02253   0.00478 0.0005606        11       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:13<00:00,  1.29it/s]
#                  all        680        868      0.929      0.958      0.965      0.567
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    148/999     14.3G   0.02228  0.004692 0.0005968        11       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        867       0.93      0.957      0.963      0.569
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    149/999     14.3G   0.02238  0.004703 0.0005325        12       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.929      0.958      0.962      0.573
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    150/999     14.3G    0.0221  0.004582 0.0006185        21       640: 100% 120/120 [01:45<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 17/17 [00:12<00:00,  1.33it/s]
#                  all        680        868      0.935      0.958      0.964      0.561
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
# - **batch-size:** số lượng mỗi ảnh của từng batch để mô hình xử lý. Truyền -1 để mô hình tự tính toán kích thước của batch. Mặc định 32.
# - **img:** kích thước ảnh đầu vào. Mặc đinh 640
# - **task:** loại công việc thực hiện gồm: val (đánh giá trên tập validation), test (đánh giá trên tập test), speed (đánh giá tốc độ của mô hình), study (phân tích mô hình)
# - **single-cls:** coi dataset như dataset chỉ có một lớp
# - **save-txt:** lưu kết quả phát hiện vị trí biển số thành file txt
# - **save-hybrid:** lưu kết quả phát hiện vị trí biển số và vị trí ground truth
# - **project:** đường dẫn của thư mục project, nơi mà mô hình sẽ lưu các thư mục chạy thử nghiệm
# - **name:** tên thư mục chạy thử nghiệm, lưu trữ kết quả training, evaluation
#
# Ngoài ra, mô hình còn nhận thêm các tham số khác. Mô hình sẽ sử dụng các giá trị mặc định của tham số nếu tham số để trống. Tham khảo thêm tại soucre code của Ultralytic https://github.com/ultralytics/yolov5.

# %% [markdown]
# ## Đánh giá trên tập validation

# %% [markdown]
# ### Chạy đánh giá trên tập validation

# %%
# !python val.py --weights /content/drive/MyDrive/Yolov5_censor_license_plate_config/best.pt --data {dataset.location}/data.yaml --task val --conf-thres 0.25
# Out:
# val: data=/content/datasets/license_plate-2/data.yaml, weights=['/content/drive/MyDrive/Yolov5_censor_license_plate_config/best.pt'], batch_size=32, imgsz=640, conf_thres=0.25, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.25 > 0.001 produces invalid results ⚠️
# YOLOv5 🚀 v6.1-266-ged95502 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 367 layers, 46129818 parameters, 0 gradients
# val: Scanning '/content/datasets/license_plate-2/valid/labels.cache' images and labels... 680 found, 0 missing, 1 empty, 0 corrupt: 100% 680/680 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5    mAP@.75 mAP@.5:.95: 100% 22/22 [00:23<00:00,  1.08s/it]
#                  all        680        864      0.938      0.954      0.971      0.697       0.62
#              bien_do        680        117      0.956      0.933      0.983      0.543      0.559
#      bien_ngoai_giao        680         37       0.99          1      0.995       0.94      0.775
#           bien_trang        680        452      0.819      0.927      0.922       0.62      0.561
#            bien_vang        680        197      0.924      0.926      0.963      0.638      0.582
#            bien_xanh        680         61          1      0.984      0.991      0.743      0.623
# Speed: 0.2ms pre-process, 25.9ms inference, 1.6ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp4

# %% [markdown]
# ### Kết quả đánh giá trên tập validation

# %%
for imageName in glob.glob('/content/yolov5/runs/val/exp/*.png'):
    print(os.path.basename(imageName).upper())
    img = cv2.imread(imageName)
    img = imutils.resize(img, width=800)
    cv2_imshow(img)
    print('\n\n\n')
# Out:
# R_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7FD9DB3D91D0>
# P_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7FD9DAB24950>
# F1_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7FD9DB3D91D0>
# PR_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7FD9DB3D91D0>
# CONFUSION_MATRIX.PNG
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7FD9DAB30D50>

# %% [markdown]
# ## Đánh giá trên tập test

# %% [markdown]
# ### Chạy đánh giá trên tập test

# %%
# !python val.py --weights /content/drive/MyDrive/Yolov5_censor_license_plate_config/best.pt --data {dataset.location}/data.yaml --task test --iou-thres 0.5 --conf-thres 0.25 --verbose
# Out:
# val: data=/content/datasets/license_plate-2/data.yaml, weights=['/content/drive/MyDrive/Yolov5_censor_license_plate_config/best.pt'], batch_size=32, imgsz=640, conf_thres=0.25, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.25 > 0.001 produces invalid results ⚠️
# YOLOv5 🚀 v6.1-266-ged95502 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 367 layers, 46129818 parameters, 0 gradients
# test: Scanning '/content/datasets/license_plate-2/test/labels' images and labels...347 found, 0 missing, 0 empty, 0 corrupt: 100% 347/347 [00:00<00:00, 2072.04it/s]
# test: New cache created: /content/datasets/license_plate-2/test/labels.cache
#                Class     Images     Labels          P          R     mAP@.5    mAP@.75 mAP@.5:.95: 100% 11/11 [00:13<00:00,  1.26s/it]
#                  all        347        436      0.909      0.967      0.962      0.743      0.628
#              bien_do        347         69          1      0.948      0.984      0.728      0.606
#      bien_ngoai_giao        347         11          1          1      0.995      0.995      0.751
#           bien_trang        347        233       0.71      0.933      0.891      0.541      0.527
#            bien_vang        347         88      0.837      0.955      0.944      0.689      0.591
#            bien_xanh        347         35          1          1      0.995      0.762      0.662
# Speed: 0.6ms pre-process, 26.3ms inference, 1.7ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp5

# %% [markdown]
# ### Kết quả đánh giá trên tập test

# %%
for imageName in glob.glob('runs/val/exp2/*.png'):
    print(os.path.basename(imageName).upper())
    img = cv2.imread(imageName)
    img = imutils.resize(img, width=800)
    cv2_imshow(img)
    print('\n\n\n')
# Out:
# R_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7F38647B4050>
# P_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7F3863E45DD0>
# F1_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7F38647B4FD0>
# PR_CURVE.PNG
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7F3863E45DD0>
# CONFUSION_MATRIX.PNG
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F3863E45D50>

# %% [markdown]
# # Step 5: Run Inference  With Trained Weights
# Nếu muốn làm mờ biển số trên video, chỉ cần truyền tham số **censor** và **source** cùng đường dẫn tới video muốn làm mờ.
#
# Vị trí lưu kết quả được mô hình thông báo phía cuối output của cell.
#
# ```shell
# python detect.py --censor --source 0  # webcam
#                                    img.jpg  # image
#                                    vid.mp4  # video
#                                    path/  # directory
#                                    path/*.jpg  # glob
#                                    'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                                    'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights /content/drive/MyDrive/Project/Yolov5/Run_18_June_222/weights/best.pt --censor --source /content/drive/MyDrive/DatasetCS114/testing_Trim.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/Project/Yolov5/Run_18_June_222/weights/best.pt'], source=/content/drive/MyDrive/DatasetCS114/testing_Trim.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False
736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.028s)
# video 1/1 (101/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.028s)
# video 1/1 (102/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.028s)
# video 1/1 (103/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, 1 bien_vang, Done. (0.028s)
# video 1/1 (104/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.028s)
# video 1/1 (105/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.031s)
# video 1/1 (106/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (107/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (108/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (109/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.030s)
# video 1/1 (110/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (111/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (112/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (113/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (114/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (115/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (116/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.028s)
# video 1/1 (117/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (118/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.027s)
# video 1/1 (119/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.027s)
# video 1/1 (120/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.026s)
# video 1/1 (121/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.027s)
# video 1/1 (122/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (123/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (124/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (125/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.041s)
# video 1/1 (126/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (127/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.027s)
# video 1/1 (128/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (129/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (130/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (131/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (132/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.027s)
# video 1/1 (133/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (134/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (135/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (136/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.027s)
# video 1/1 (137/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (138/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (139/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (140/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (141/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (142/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.027s)
# video 1/1 (143/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (144/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (145/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, 1 bien_vang, Done. (0.025s)
# video 1/1 (146/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (147/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, 1 bien_vang, Done. (0.024s)
# video 1/1 (148/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (149/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, 1 bien_vang, Done. (0.025s)
# video 1/1 (150/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, 1 bien_vang, Done. (0.024s)
# video 1/1 (151/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (152/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (153/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (154/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (155/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.026s)
# video 1/1 (156/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (157/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (158/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.030s)
# video 1/1 (159/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, 1 bien_xanh, Done. (0.027s)
# video 1/1 (160/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (161/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, 1 bien_xanh, Done. (0.024s)
# video 1/1 (162/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (163/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (164/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.027s)
# video 1/1 (165/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, 1 bien_xanh, Done. (0.024s)
# video 1/1 (166/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (167/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (168/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (169/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (170/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (171/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (172/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (173/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (174/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (175/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.025s)
# video 1/1 (176/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (177/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (178/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (179/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (180/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (181/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (182/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (183/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (184/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (185/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (186/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (187/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (188/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.025s)
# video 1/1 (189/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (190/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (191/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (192/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (193/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (194/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.026s)
# video 1/1 (195/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (196/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (197/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (198/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (199/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.026s)
# video 1/1 (200/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (201/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (202/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (203/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.025s)
# video 1/1 (204/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (205/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (206/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (207/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (208/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.026s)
# video 1/1 (209/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (210/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 Done. (0.024s)
# video 1/1 (211/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (212/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (213/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.027s)
# video 1/1 (214/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (215/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (216/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (217/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (218/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (219/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.078s)
# video 1/1 (220/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.028s)
# video 1/1 (221/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (222/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (223/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.029s)
# video 1/1 (224/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (225/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (226/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (227/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (228/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (229/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.110s)
# video 1/1 (230/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.040s)
# video 1/1 (231/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (232/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (233/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (234/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.027s)
# video 1/1 (235/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.026s)
# video 1/1 (236/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (237/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.030s)
# video 1/1 (238/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (239/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.026s)
# video 1/1 (240/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (241/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (242/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (243/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (244/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (245/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (246/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (247/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (248/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (249/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (250/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (251/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.024s)
# video 1/1 (252/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (253/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.026s)
# video 1/1 (254/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.029s)
# video 1/1 (255/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (256/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (257/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.023s)
# video 1/1 (258/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (259/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (260/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (261/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (262/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (263/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (264/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (265/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (266/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (267/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (268/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (269/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (270/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (271/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (272/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (273/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (274/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (275/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (276/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (277/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (278/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.025s)
# video 1/1 (279/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (280/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (281/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (282/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (283/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (284/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (285/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (286/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (287/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (288/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.032s)
# video 1/1 (289/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (290/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (291/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.030s)
# video 1/1 (292/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (293/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (294/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (295/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (296/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# ...
# video 1/1 (639/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (640/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.025s)
# video 1/1 (641/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.022s)
# video 1/1 (642/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (643/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.020s)
# video 1/1 (644/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (645/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (646/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.031s)
# video 1/1 (647/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.020s)
# video 1/1 (648/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (649/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (650/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (651/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (652/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (653/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.020s)
# video 1/1 (654/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (655/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (656/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (657/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (658/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (659/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (660/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.020s)
# video 1/1 (661/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (662/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (663/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.020s)
# video 1/1 (664/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (665/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (666/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (667/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (668/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (669/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (670/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (671/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (672/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (673/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (674/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.024s)
# video 1/1 (675/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (676/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (677/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (678/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (679/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (680/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (681/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (682/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (683/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (684/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (685/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (686/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (687/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (688/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (689/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (690/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.026s)
# video 1/1 (691/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (692/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (693/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (694/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (695/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (696/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.023s)
# video 1/1 (697/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (698/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (699/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (700/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 3 bien_trangs, Done. (0.021s)
# video 1/1 (701/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (702/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (703/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (704/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (705/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.025s)
# video 1/1 (706/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (707/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.022s)
# video 1/1 (708/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 2 bien_trangs, Done. (0.021s)
# video 1/1 (709/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.029s)
# video 1/1 (710/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (711/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (712/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (713/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (714/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (715/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (716/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (717/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (718/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (719/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (720/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (721/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.025s)
# video 1/1 (722/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (723/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (724/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (725/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (726/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (727/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (728/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.022s)
# video 1/1 (729/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (730/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (731/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (732/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.023s)
# video 1/1 (733/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# video 1/1 (734/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (735/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.024s)
# video 1/1 (736/736) /content/drive/.shortcut-targets-by-id/1EvdfzlSDHz1CR3Guwi5F4rcwyDsl6vli/DatasetCS114/testing_Trim.mp4: 384x640 1 bien_trang, Done. (0.021s)
# Speed: 0.6ms pre-process, 24.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
